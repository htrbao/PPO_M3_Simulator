# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = "./_saved_csv/vipi_10layer_128_halfepoch_10layers_32channels_1e-05_6400_not_share_20240925/csv_log_count_win.csv"

# %%
max_cols = 16
data = pd.read_csv(file, header=None).iloc[:,:max_cols]

# data = data.div(data.sum(axis=1), axis=0)

# %%
data.sum(axis=1)
# Out:
# 0    1021
# 1    1022
# 2    1014
# 3    1012
# dtype: int64

# %%
data.mean(axis=1)
# Out:
# 0    63.8125
# 1    63.8750
# 2    63.3750
# 3    63.2500
# dtype: float64

# %%
ax = data.plot.bar(figsize=(20, 8), grid=True)
ax.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
ax.set_ylabel('Num Game Win')
ax.set_xlabel('Trained Step')
# Out:
# Text(0.5, 0, 'Trained Step')

# %%
import os
ax.figure.savefig(os.path.join(os.path.dirname(file), "img.jpg"))
